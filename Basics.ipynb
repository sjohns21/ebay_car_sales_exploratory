# %% [markdown]
# # to analyze used car listing data from ebay

# %%
import pandas as pd
import numpy as np
autos=pd.read_csv('autos.csv', encoding='Latin-1')

# %%
autos
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
# dateCrawled            50000 non-null object
# name                   50000 non-null object
# seller                 50000 non-null object
# offerType              50000 non-null object
# price                  50000 non-null object
# abtest                 50000 non-null object
# vehicleType            44905 non-null object
# yearOfRegistration     50000 non-null int64
# gearbox                47320 non-null object
# powerPS                50000 non-null int64
# model                  47242 non-null object
# odometer               50000 non-null object
# monthOfRegistration    50000 non-null int64
# fuelType               45518 non-null object
# brand                  50000 non-null object
# notRepairedDamage      40171 non-null object
# dateCreated            50000 non-null object
# nrOfPictures           50000 non-null int64
# ...

# %%
autos.head()
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offerType   price   abtest vehicleType  yearOfRegistration  \
# 0  privat   Angebot  $5,000  control         bus                2004
# 1  privat   Angebot  $8,500  control   limousine                1997
# 2  privat   Angebot  $8,990     test   limousine                2009
# 3  privat   Angebot  $4,350  control  kleinwagen                2007
# 4  privat   Angebot  $1,350     test       kombi                2003
#
#      gearbox  powerPS   model   odometer  monthOfRegistration fuelType  \
# ...

# %% [markdown]
# several columns have number of null values. listing names look extremely non-uniform

# %%
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
autos=pd.read_csv('autos.csv', encoding='Latin-1')
d={'yearOfRegistration':'registration_year','monthOfRegistration':'registration_month','notRepairedDamage':'unrepaired_damage','dateCreated':'ad_created'}
autos.rename(columns=d,inplace=True)
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'registration_year', 'gearbox', 'powerPS', 'model',
#        'odometer', 'registration_month', 'fuelType', 'brand',
#        'unrepaired_damage', 'ad_created', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
autos.columns=autos.columns.str.replace('[.(A-Z)]','_\g<0>')
autos.columns
# Out:
# Index(['date_Crawled', 'name', 'seller', 'offer_Type', 'price', 'abtest',
#        'vehicle_Type', 'registration_year', 'gearbox', 'power_P_S', 'model',
#        'odometer', 'registration_month', 'fuel_Type', 'brand',
#        'unrepaired_damage', 'ad_created', 'nr_Of_Pictures', 'postal_Code',
#        'last_Seen'],
#       dtype='object')

# %%
autos.columns=autos.columns.str.lower()
autos.columns
# Out:
# Index(['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
#        'vehicle_type', 'registration_year', 'gearbox', 'power_p_s', 'model',
#        'odometer', 'registration_month', 'fuel_type', 'brand',
#        'unrepaired_damage', 'ad_created', 'nr_of_pictures', 'postal_code',
#        'last_seen'],
#       dtype='object')

# %%
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type   price   abtest vehicle_type  registration_year  \
# 0  privat    Angebot  $5,000  control          bus               2004
# 1  privat    Angebot  $8,500  control    limousine               1997
# 2  privat    Angebot  $8,990     test    limousine               2009
# 3  privat    Angebot  $4,350  control   kleinwagen               2007
# 4  privat    Angebot  $1,350     test        kombi               2003
#
#      gearbox  power_p_s   model   odometer  registration_month fuel_type  \
# ...

# %% [markdown]
# changed column labels from camelcase to snakecase to fit python standards. renamed some column labels for added clarity.

# %%
autos.describe()
# Out:
#        registration_year     power_p_s  registration_month  nr_of_pictures  \
# count       50000.000000  50000.000000        50000.000000         50000.0
# mean         2005.073280    116.355920            5.723360             0.0
# std           105.712813    209.216627            3.711984             0.0
# min          1000.000000      0.000000            0.000000             0.0
# 25%          1999.000000     70.000000            3.000000             0.0
# 50%          2003.000000    105.000000            6.000000             0.0
# 75%          2008.000000    150.000000            9.000000             0.0
# max          9999.000000  17700.000000           12.000000             0.0
#
#         postal_code
# count  50000.000000
# mean   50813.627300
# std    25779.747957
# min     1067.000000
# 25%    30451.000000
# 50%    49577.000000
# 75%    71540.000000
# max    99998.000000

# %% [markdown]
# can drop nr_of_pictures

# %%
autos.describe(exclude=np.number)
# Out:
#                date_crawled         name  seller offer_type  price abtest  \
# count                 50000        50000   50000      50000  50000  50000
# unique                48213        38754       2          2   2357      2
# top     2016-03-12 16:06:22  Ford_Fiesta  privat    Angebot     $0   test
# freq                      3           78   49999      49999   1421  25756
#
#        vehicle_type  gearbox  model   odometer fuel_type       brand  \
# count         44905    47320  47242      50000     45518       50000
# unique            8        2    245         13         7          40
# top       limousine  manuell   golf  150,000km    benzin  volkswagen
# freq          12859    36993   4024      32424     30107       10687
#
#        unrepaired_damage           ad_created            last_seen
# count              40171                50000                50000
# unique                 2                   76                39481
# ...

# %% [markdown]
# can drop seller, offer_type columns
# must change price and odometer columns to numeric type

# %%
autos['price']=autos['price'].str.replace('$','').str.replace(',','').astype(int)

# %%
autos['odometer']=autos['odometer'].astype(str)
autos['odometer']=autos['odometer'].str.replace('km','').str.replace(',','').astype(int)

# %%
autos=autos.rename(columns={'odometer':'odometer_km'})

# %%
autos.columns
# Out:
# Index(['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
#        'vehicle_type', 'registration_year', 'gearbox', 'power_p_s', 'model',
#        'odometer_km', 'registration_month', 'fuel_type', 'brand',
#        'unrepaired_damage', 'ad_created', 'nr_of_pictures', 'postal_code',
#        'last_seen'],
#       dtype='object')

# %%
autos['odometer_km'].unique().shape
# Out:
# (13,)

# %%
autos['odometer_km'].describe()
# Out:
# count     50000.000000
# mean     125732.700000
# std       40042.211706
# min        5000.000000
# 25%      125000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: odometer_km, dtype: float64

# %%
autos['odometer_km'].value_counts().sort_index()
# Out:
# 5000        967
# 10000       264
# 20000       784
# 30000       789
# 40000       819
# 50000      1027
# 60000      1164
# 70000      1230
# 80000      1436
# 90000      1757
# 100000     2169
# 125000     5170
# 150000    32424
# Name: odometer_km, dtype: int64

# %% [markdown]
# it seems that 150000km is the maximum mileage description, encompasing all vehicles with mileage over 150000km. it also seems that 5000 is the lowest possible vehicle mileage. we'll remove both of these to remove the abiquity behind the true mileage of these vehicles.

# %%
autos=autos[autos['odometer_km'].between(10000,125000)]

# %%
autos['price'].unique().shape
# Out:
# (1797,)

# %%
autos['price'].describe()
# Out:
# count    1.660900e+04
# mean     1.279336e+04
# std      2.421522e+05
# min      0.000000e+00
# 25%      2.750000e+03
# 50%      6.500000e+03
# 75%      1.300000e+04
# max      2.732222e+07
# Name: price, dtype: float64

# %%
autos['price'].value_counts().sort_index()
# Out:
# 0           289
# 1            28
# 2             1
# 10            1
# 12            1
# 14            1
# 20            1
# 25            1
# 30            2
# 47            1
# 49            1
# 50            8
# 55            1
# 60            1
# 65            2
# 66            1
# 70            4
# 75            1
# 80            3
# 99            4
# 100          26
# 110           1
# 115           1
# 117           1
# 120           5
# 125           2
# 130           1
# 139           1
# 140           1
# 145           1
#            ...
# 105000        1
# 109999        1
# 115991        1
# 116000        1
# 119900        1
# 120000        2
# 128000        1
# 129000        1
# 130000        1
# 135000        1
# 137999        1
# 139997        1
# 145000        1
# 151990        1
# 155000        1
# 163500        1
# 163991        1
# 169000        1
# 169999        1
# 180000        1
# 190000        1
# 220000        1
# 259000        1
# 299000        1
# ...

# %% [markdown]
# we may want to remove the lower outliers in the price column, especially 0 and 1. we may also want to remove the upper outliers, especially those above 1 million

# %%
autos=autos[autos['price'].between(3,999999)]

# %%
autos['date_crawled'].str[:10].value_counts(normalize=True,dropna=False).sort_index()
# Out:
# 2016-03-05    0.028182
# 2016-03-06    0.013631
# 2016-03-07    0.034445
# 2016-03-08    0.031252
# 2016-03-09    0.031252
# 2016-03-10    0.032603
# 2016-03-11    0.033339
# 2016-03-12    0.038865
# 2016-03-13    0.016516
# 2016-03-14    0.036594
# 2016-03-15    0.032357
# 2016-03-16    0.028366
# 2016-03-17    0.029533
# 2016-03-18    0.013017
# 2016-03-19    0.038681
# 2016-03-20    0.038436
# 2016-03-21    0.035427
# 2016-03-22    0.031866
# 2016-03-23    0.030699
# 2016-03-24    0.029717
# 2016-03-25    0.031313
# 2016-03-26    0.032725
# 2016-03-27    0.031682
# 2016-03-28    0.034752
# 2016-03-29    0.036102
# 2016-03-30    0.033155
# 2016-03-31    0.031559
# 2016-04-01    0.036532
# 2016-04-02    0.036716
# 2016-04-03    0.040830
# 2016-04-04    0.033585
# 2016-04-05    0.012280
# 2016-04-06    0.002210
# 2016-04-07    0.001781
# Name: date_crawled, dtype: float64

# %% [markdown]
# the frequency distribution looks relatively consistent, but there seems to be a sharp dropoff during the last two days

# %%
autos['ad_created'].str[:10].value_counts(normalize=True,dropna=False).sort_index()
# Out:
# 2015-06-11    0.000061
# 2015-08-10    0.000061
# 2015-09-09    0.000061
# 2015-11-10    0.000061
# 2015-12-30    0.000061
# 2016-01-03    0.000061
# 2016-01-10    0.000061
# 2016-01-22    0.000061
# 2016-01-27    0.000123
# 2016-02-01    0.000061
# 2016-02-05    0.000061
# 2016-02-07    0.000061
# 2016-02-09    0.000061
# 2016-02-14    0.000061
# 2016-02-16    0.000061
# 2016-02-17    0.000061
# 2016-02-18    0.000061
# 2016-02-19    0.000123
# 2016-02-20    0.000061
# 2016-02-21    0.000123
# 2016-02-23    0.000184
# 2016-02-24    0.000061
# 2016-02-25    0.000184
# 2016-02-26    0.000061
# 2016-02-27    0.000123
# 2016-02-28    0.000368
# 2016-02-29    0.000246
# 2016-03-01    0.000061
# 2016-03-02    0.000184
# 2016-03-03    0.000737
#                 ...
# 2016-03-09    0.031989
# 2016-03-10    0.032111
# 2016-03-11    0.033401
# 2016-03-12    0.038620
# 2016-03-13    0.017928
# 2016-03-14    0.035243
# 2016-03-15    0.032418
# 2016-03-16    0.028919
# 2016-03-17    0.029164
# ...

# %% [markdown]
# the frequency of ad creation date trends upward. this could be due to the fact that many of the ads posted earlier in the time interval expired by the time the crawling took place.

# %%
autos['last_seen'].str[:10].value_counts(normalize=True,dropna=False).sort_index()
# Out:
# 2016-03-05    0.000860
# 2016-03-06    0.003561
# 2016-03-07    0.004052
# 2016-03-08    0.004666
# 2016-03-09    0.007245
# 2016-03-10    0.009333
# 2016-03-11    0.009578
# 2016-03-12    0.020691
# 2016-03-13    0.006815
# 2016-03-14    0.010499
# 2016-03-15    0.014306
# 2016-03-16    0.012894
# 2016-03-17    0.023823
# 2016-03-18    0.007368
# 2016-03-19    0.013446
# 2016-03-20    0.018358
# 2016-03-21    0.017806
# 2016-03-22    0.019156
# 2016-03-23    0.016639
# 2016-03-24    0.016946
# 2016-03-25    0.017314
# 2016-03-26    0.014674
# 2016-03-27    0.013631
# 2016-03-28    0.017867
# 2016-03-29    0.021674
# 2016-03-30    0.022963
# 2016-03-31    0.021612
# 2016-04-01    0.022104
# 2016-04-02    0.024007
# 2016-04-03    0.024007
# 2016-04-04    0.021428
# 2016-04-05    0.139007
# 2016-04-06    0.249524
# 2016-04-07    0.152146
# Name: last_seen, dtype: float64

# %% [markdown]
# the frequency distribution trends upward with time. this makes sense, considering many of the posts were likely recrawled and only the latest crawl date is kept in the data.

# %%
autos['registration_year'].describe()
# Out:
# count    16287.000000
# mean      2008.860379
# std        140.551983
# min       1910.000000
# 25%       2003.000000
# 50%       2008.000000
# 75%       2011.000000
# max       9999.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# the registration year distribution reflects a strong left skew. there are also some clear outliers on the upper end.

# %% [markdown]
# im going to exclude cars registered outside the timeframe of 1900 to 2016

# %%
autos=autos[autos['registration_year'].between(1900,2016)]

# %%
autos['registration_year'].value_counts(normalize=True).sort_index()
# Out:
# 1910    0.000063
# 1931    0.000063
# 1934    0.000063
# 1937    0.000063
# 1941    0.000127
# 1943    0.000063
# 1948    0.000063
# 1951    0.000127
# 1952    0.000063
# 1954    0.000127
# 1955    0.000127
# 1956    0.000253
# 1957    0.000127
# 1958    0.000190
# 1959    0.000190
# 1960    0.000824
# 1961    0.000190
# 1962    0.000190
# 1963    0.000127
# 1964    0.000570
# 1965    0.000697
# 1966    0.000760
# 1967    0.001330
# 1968    0.000887
# 1969    0.001014
# 1970    0.001457
# 1971    0.001077
# 1972    0.001330
# 1973    0.000697
# 1974    0.000950
#           ...
# 1987    0.001140
# 1988    0.002344
# 1989    0.002978
# 1990    0.004815
# 1991    0.004625
# 1992    0.005322
# 1993    0.005512
# 1994    0.005258
# 1995    0.012607
# 1996    0.012797
# 1997    0.016661
# 1998    0.021793
# 1999    0.026164
# 2000    0.029585
# 2001    0.030029
# 2002    0.032056
# 2003    0.039214
# 2004    0.040165
# 2005    0.050808
# 2006    0.058220
# 2007    0.057396
# ...

# %% [markdown]
# this distribution trends upward as well. this makes sense considering the longer a car is in service, the less likely it is to be viable for resale

# %%
labels=autos['brand'].value_counts().index[:20]

# %%
di={}
for label in labels:
    di[label]=autos[autos['brand']==label]['price'].mean().astype(int)
print(di)
mean_prices=di
# Out:
# {'seat': 7268, 'citroen': 5468, 'mini': 12074, 'bmw': 15974, 'mercedes_benz': 16241, 'ford': 7017, 'renault': 4254, 'nissan': 7365, 'audi': 18612, 'toyota': 6972, 'volkswagen': 10115, 'mazda': 7083, 'fiat': 4002, 'smart': 4188, 'peugeot': 5212, 'skoda': 8389, 'opel': 5408, 'porsche': 52578, 'sonstige_autos': 15337, 'hyundai': 6983}

# %% [markdown]
# the mean brand prices reflect what one would expect. the higher ends brands tend to have higher prices than lower end brands.

# %%
di={}
for label in labels:
    di[label]=autos[autos['brand']==label]['odometer_km'].mean().astype(int)
print(di)
mileage=di
# Out:
# {'seat': 84125, 'citroen': 88415, 'mini': 73777, 'bmw': 89305, 'mercedes_benz': 85968, 'ford': 86370, 'renault': 91769, 'nissan': 86114, 'audi': 79327, 'toyota': 85583, 'volkswagen': 83863, 'mazda': 87698, 'fiat': 88041, 'smart': 81443, 'peugeot': 90357, 'skoda': 78673, 'opel': 91191, 'porsche': 75289, 'sonstige_autos': 66803, 'hyundai': 78576}

# %%
prices=pd.Series(mean_prices,name='prices').sort_values()

# %%
mileage=pd.Series(mileage,name='mileage')

# %%
top_20=pd.DataFrame({'mean price':prices})

# %%
top_20['mean price']
# Out:
# fiat               4002
# smart              4188
# renault            4254
# peugeot            5212
# opel               5408
# citroen            5468
# toyota             6972
# hyundai            6983
# ford               7017
# mazda              7083
# seat               7268
# nissan             7365
# skoda              8389
# volkswagen        10115
# mini              12074
# sonstige_autos    15337
# bmw               15974
# mercedes_benz     16241
# audi              18612
# porsche           52578
# Name: mean price, dtype: int64

# %%
top_20['mean mileage']=mileage

# %%
top_20
# Out:
#                 mean price  mean mileage
# fiat                  4002         88041
# smart                 4188         81443
# renault               4254         91769
# peugeot               5212         90357
# opel                  5408         91191
# citroen               5468         88415
# toyota                6972         85583
# hyundai               6983         78576
# ford                  7017         86370
# mazda                 7083         87698
# seat                  7268         84125
# nissan                7365         86114
# skoda                 8389         78673
# volkswagen           10115         83863
# mini                 12074         73777
# sonstige_autos       15337         66803
# bmw                  15974         89305
# mercedes_benz        16241         85968
# audi                 18612         79327
# porsche              52578         75289

# %% [markdown]
# the mean price of vehicles seems to be more a function of the brand than off the mileage. mean mileage across brands are mostly comparable, but a clear trend in mean prices is seen.
